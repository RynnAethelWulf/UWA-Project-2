# %%
import requests
from pprint import pprint
import pandas as pd
data = {}
API_KEY = "e1f3e56d62ce497fa4d15b664cbb014c"
for i in range(4):
    para = {
       "key":API_KEY,
        "dates":"2019-01-01,2020-11-30",
        "platforms":"18,1,7,4,186,187",
        "page_size":40,
        "page":i,
        "ordering":"released"
    }
    url = "https://api.rawg.io/api/games"
    data[i] = requests.get(url,params=para).json()
data[3]
# Out:
# {'count': 127832,
#  'next': 'https://api.rawg.io/api/games?dates=2019-01-01%2C2020-11-30&key=e1f3e56d62ce497fa4d15b664cbb014c&ordering=released&page=4&page_size=40&platforms=18%2C1%2C7%2C4%2C186%2C187',
#  'previous': 'https://api.rawg.io/api/games?dates=2019-01-01%2C2020-11-30&key=e1f3e56d62ce497fa4d15b664cbb014c&ordering=released&page=2&page_size=40&platforms=18%2C1%2C7%2C4%2C186%2C187',
#  'results': [{'slug': 'simplemovie',
#    'name': 'SimpleMovie',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/b66/b669d3600ee43a8d269c763a9e55532c.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 212,
#    'id': 276657,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 31,
#      'name': 'Singleplayer',
#      'slug': 'singleplayer',
#      'language': 'eng',
#      'games_count': 61255,
#      'image_background': 'https://media.rawg.io/media/games/88c/88c5b4d7c80276c03ff62aebb1a99ad4.jpg'},
#     {'id': 42398,
#      'name': 'Инди',
#      'slug': 'indi-2',
#      'language': 'rus',
#      'games_count': 27801,
#      'image_background': 'https://media.rawg.io/media/games/929/9295e55ce69cf5337c567983cf8b4137.jpeg'},
#     {'id': 42399,
#      'name': 'Казуальная игра',
#      'slug': 'kazualnaia-igra',
#      'language': 'rus',
#      'games_count': 14854,
#      'image_background': 'https://media.rawg.io/media/games/598/598d272e2fc09f7f5362ddd37868a329.jpg'},
#     {'id': 42413,
#      'name': 'Симулятор',
#      'slug': 'simuliator',
#      'language': 'rus',
#      'games_count': 7748,
#      'image_background': 'https://media.rawg.io/media/screenshots/9b9/9b9d1fcf7b2a6cc7926328c83e13a66a.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/b66/b669d3600ee43a8d269c763a9e55532c.jpg'},
#     {'id': 1775959,
#      'image': 'https://media.rawg.io/media/screenshots/228/2285c6627d1c4f5f21e3a90fe76f8fe3.jpg'},
#     {'id': 1775960,
#      'image': 'https://media.rawg.io/media/screenshots/943/943078c70b52eeeddee14a78aa95049e.jpg'},
#     {'id': 1775961,
#      'image': 'https://media.rawg.io/media/screenshots/bdd/bddbf9f4662a394bdaf7ca26ee8596bd.jpg'},
#     {'id': 1775962,
#      'image': 'https://media.rawg.io/media/screenshots/f65/f65d1197989146775b0bb1dc11536b90.jpg'},
#     {'id': 1775963,
#      'image': 'https://media.rawg.io/media/screenshots/a69/a69ad19f614bd972d0442ec70bc7894f.jpg'},
#     {'id': 1775964,
#      'image': 'https://media.rawg.io/media/screenshots/884/88471098c535a28641c589e705a6bfbc.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 40, 'name': 'Casual', 'slug': 'casual'},
#     {'id': 51, 'name': 'Indie', 'slug': 'indie'},
#     {'id': 14, 'name': 'Simulation', 'slug': 'simulation'}]},
#   {'slug': 'today-and-tomorrow',
#    'name': 'Today and Tomorrow',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/364/3642d8e8604cdfc4193b49ddf2eeb465.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 28,
#    'id': 282201,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 45,
#      'name': '2D',
#      'slug': '2d',
#      'language': 'eng',
#      'games_count': 47748,
#      'image_background': 'https://media.rawg.io/media/games/91c/91c4f377c1e09755b60a0102c5252843.jpg'},
#     {'id': 122,
#      'name': 'Pixel Graphics',
#      'slug': 'pixel-graphics',
#      'language': 'eng',
#      'games_count': 22577,
#      'image_background': 'https://media.rawg.io/media/screenshots/f3b/f3b3c2e6ea6aac2cfaf4ccfa4aaa08f4.jpg'},
#     {'id': 287,
#      'name': 'Political',
#      'slug': 'political',
#      'language': 'eng',
#      'games_count': 195,
#      'image_background': 'https://media.rawg.io/media/screenshots/55f/55f5bea9e37aeeff3417f0b2c7b82c40.jpg'},
#     {'id': 31,
#      'name': 'Singleplayer',
#      'slug': 'singleplayer',
#      'language': 'eng',
#      'games_count': 61255,
#      'image_background': 'https://media.rawg.io/media/games/88c/88c5b4d7c80276c03ff62aebb1a99ad4.jpg'},
#     {'id': 1158,
#      'name': 'creative',
#      'slug': 'creative',
#      'language': 'eng',
#      'games_count': 418,
#      'image_background': 'https://media.rawg.io/media/screenshots/326/326d013be9deae487c506d438e838538.jpg'},
#     {'id': 2252,
#      'name': 'literature',
#      'slug': 'literature',
#      'language': 'eng',
#      'games_count': 20,
#      'image_background': 'https://media.rawg.io/media/screenshots/9d7/9d785fe35e8124a64854234c0c3fdafb.jpg'},
#     {'id': 3618,
#      'name': 'climate-change',
#      'slug': 'climate-change',
#      'language': 'eng',
#      'games_count': 24,
#      'image_background': 'https://media.rawg.io/media/screenshots/7df/7dfd1482dc78a8f30dbc3f9f57637b97.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/364/3642d8e8604cdfc4193b49ddf2eeb465.jpg'},
#     {'id': 1798484,
#      'image': 'https://media.rawg.io/media/screenshots/364/3642d8e8604cdfc4193b49ddf2eeb465.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 34, 'name': 'Educational', 'slug': 'educational'},
#     {'id': 83, 'name': 'Platformer', 'slug': 'platformer'}]},
#   {'slug': 'balloon-buddies-alpha',
#    'name': 'Balloon Buddies Alpha',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/62c/62c3c50e06a61fc68ba7d6bbdf32ef1f.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 115,
#    'id': 282217,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 72,
#      'name': 'Local Multiplayer',
#      'slug': 'local-multiplayer',
#      'language': 'eng',
#      'games_count': 6989,
#      'image_background': 'https://media.rawg.io/media/games/1e5/1e5e33b88be978f451196a751424a72e.jpg'},
#     {'id': 7,
#      'name': 'Multiplayer',
#      'slug': 'multiplayer',
#      'language': 'eng',
#      'games_count': 18474,
#      'image_background': 'https://media.rawg.io/media/games/490/49016e06ae2103881ff6373248843069.jpg'},
#     {'id': 411,
#      'name': 'cooperative',
#      'slug': 'cooperative',
#      'language': 'eng',
#      'games_count': 2124,
#      'image_background': 'https://media.rawg.io/media/games/c98/c9839e65d2debbcbc7e0f9f76920bab8.jpg'},
#     {'id': 639,
#      'name': 'Roguelike',
#      'slug': 'roguelike',
#      'language': 'eng',
#      'games_count': 3365,
#      'image_background': 'https://media.rawg.io/media/games/fd9/fd92f105dcd6491bc5d61135033d1f19.jpg'},
#     {'id': 640,
#      'name': 'Roguelite',
#      'slug': 'roguelite',
#      'language': 'eng',
#      'games_count': 1044,
#      'image_background': 'https://media.rawg.io/media/screenshots/244/244734c34364554c64d9cd059cc90c73.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/62c/62c3c50e06a61fc68ba7d6bbdf32ef1f.jpg'},
#     {'id': 1798519,
#      'image': 'https://media.rawg.io/media/screenshots/8ce/8ce61b92878c9045f05231c024273746.jpg'},
#     {'id': 1798520,
#      'image': 'https://media.rawg.io/media/screenshots/a00/a002c613aa6ac216b1d8605fe1d2a983.jpg'},
#     {'id': 1798521,
#      'image': 'https://media.rawg.io/media/screenshots/af9/af9fa8caee49a48b83f261d0f2427b1c.jpg'},
#     {'id': 1798522,
#      'image': 'https://media.rawg.io/media/screenshots/230/230f0e916727da4750dae7807bf68f13.jpg'},
#     {'id': 1798523,
#      'image': 'https://media.rawg.io/media/screenshots/356/356796705ad8390a22ff8accc54a4e93.jpg'},
#     {'id': 1798524,
#      'image': 'https://media.rawg.io/media/screenshots/62c/62c3c50e06a61fc68ba7d6bbdf32ef1f.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}}],
#    'genres': [{'id': 4, 'name': 'Action', 'slug': 'action'}]},
#   {'slug': 'boxer-elgoblinrojo',
#    'name': 'BOXer (ElGoblinRojo)',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 171, 'name': 'Web', 'slug': 'web'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/3c1/3c190aeb6860c4bd130885d85342d9eb.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 8,
#    'id': 282231,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 2595,
#      'name': 'click',
#      'slug': 'click',
#      'language': 'eng',
#      'games_count': 3753,
#      'image_background': 'https://media.rawg.io/media/screenshots/4e3/4e3f8d57630fac227a3c7c9609c86b9c.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/3c1/3c190aeb6860c4bd130885d85342d9eb.jpg'},
#     {'id': 1798561,
#      'image': 'https://media.rawg.io/media/screenshots/3c1/3c190aeb6860c4bd130885d85342d9eb.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 14, 'name': 'Web', 'slug': 'web'}}],
#    'genres': [{'id': 6, 'name': 'Fighting', 'slug': 'fighting'}]},
#   {'slug': 'menu-man',
#    'name': 'Menu Man',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/ab6/ab6a3a6ccee9b5244cf8d701c1cfde68.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 48,
#    'id': 282240,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 260,
#      'name': 'GameMaker',
#      'slug': 'gamemaker',
#      'language': 'eng',
#      'games_count': 4026,
#      'image_background': 'https://media.rawg.io/media/screenshots/611/61164de1b27edd3108681208c0055384.jpg'},
#     {'id': 982,
#      'name': 'run',
#      'slug': 'run',
#      'language': 'eng',
#      'games_count': 2441,
#      'image_background': 'https://media.rawg.io/media/screenshots/12c/12cf43dc7727ef4143d36e76c67636c3.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/ab6/ab6a3a6ccee9b5244cf8d701c1cfde68.jpg'},
#     {'id': 1798572,
#      'image': 'https://media.rawg.io/media/screenshots/c4c/c4c812707623435afa6d23faf77023a1.jpg'},
#     {'id': 1798573,
#      'image': 'https://media.rawg.io/media/screenshots/687/687593ba0258a6e7ae0988a96e8aa02a.jpg'},
#     {'id': 1798574,
#      'image': 'https://media.rawg.io/media/screenshots/9b3/9b3cb7554b3f63ce4481db7616cb5e5b.jpg'},
#     {'id': 1798575,
#      'image': 'https://media.rawg.io/media/screenshots/ab6/ab6a3a6ccee9b5244cf8d701c1cfde68.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': []},
#   {'slug': 'stale-bread',
#    'name': 'Stale Bread',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/2d5/2d5e5c051cd9c1ee4759ac282e315057.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 16,
#    'id': 282252,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 136,
#      'name': 'Music',
#      'slug': 'music',
#      'language': 'eng',
#      'games_count': 12278,
#      'image_background': 'https://media.rawg.io/media/screenshots/112/112c9ecfe850e318bb999660361782bb.jpeg'},
#     {'id': 1129,
#      'name': 'art',
#      'slug': 'art',
#      'language': 'eng',
#      'games_count': 4335,
#      'image_background': 'https://media.rawg.io/media/games/bef/bef40c8ee09ad001c0f0b2cf0d07f20e.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/2d5/2d5e5c051cd9c1ee4759ac282e315057.jpg'},
#     {'id': 1798601,
#      'image': 'https://media.rawg.io/media/screenshots/2d5/2d5e5c051cd9c1ee4759ac282e315057.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': []},
#   {'slug': 'shifter-saffronsushi',
#    'name': 'SHIFTER (SaffronSushi)',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/865/865a7e99cc5d4a696b519a6203a008ef.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 33,
#    'id': 282270,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 646,
#      'name': 'maze',
#      'slug': 'maze',
#      'language': 'eng',
#      'games_count': 2205,
#      'image_background': 'https://media.rawg.io/media/screenshots/dd4/dd422615392921e68977d3698c703f27.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/865/865a7e99cc5d4a696b519a6203a008ef.jpg'},
#     {'id': 1798637,
#      'image': 'https://media.rawg.io/media/screenshots/0c1/0c1b9851d369a5fddc3cdafe1befc287.jpg'},
#     {'id': 1798638,
#      'image': 'https://media.rawg.io/media/screenshots/5be/5bef45681c80b8b9333969413149fc9b.jpg'},
#     {'id': 1798639,
#      'image': 'https://media.rawg.io/media/screenshots/c15/c15d967163017c431697ab81724bee9f.jpg'},
#     {'id': 1798640,
#      'image': 'https://media.rawg.io/media/screenshots/865/865a7e99cc5d4a696b519a6203a008ef.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 7, 'name': 'Puzzle', 'slug': 'puzzle'}]},
#   {'slug': 'flip-it',
#    'name': 'Flip It!',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/251/25198133219a53f35b64a8a8ef84afa9.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 14,
#    'id': 282286,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 112,
#      'name': 'Minimalist',
#      'slug': 'minimalist',
#      'language': 'eng',
#      'games_count': 4650,
#      'image_background': 'https://media.rawg.io/media/screenshots/6f9/6f9348edd93d9c25d6cc4ed2659703a6.jpg'},
#     {'id': 111,
#      'name': 'Short',
#      'slug': 'short',
#      'language': 'eng',
#      'games_count': 8318,
#      'image_background': 'https://media.rawg.io/media/games/0be/0bea0a08a4d954337305391b778a7f37.jpg'},
#     {'id': 60,
#      'name': 'Touch-Friendly',
#      'slug': 'touch-friendly',
#      'language': 'eng',
#      'games_count': 831,
#      'image_background': 'https://media.rawg.io/media/games/d03/d030347839f74454afcd1008248b08ae.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/251/25198133219a53f35b64a8a8ef84afa9.jpg'},
#     {'id': 1798676,
#      'image': 'https://media.rawg.io/media/screenshots/0f7/0f7c7f6a3aeec3b035e5303d81110c20.jpg'},
#     {'id': 1798677,
#      'image': 'https://media.rawg.io/media/screenshots/fe5/fe523e2545059028bf8c4eacdddff2d9.jpg'},
#     {'id': 1798678,
#      'image': 'https://media.rawg.io/media/screenshots/251/25198133219a53f35b64a8a8ef84afa9.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}}],
#    'genres': [{'id': 4, 'name': 'Action', 'slug': 'action'}]},
#   {'slug': 'dangan-gb',
#    'name': 'Dangan GB',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/40c/40cb14d5186fb30fc1a1705c8dbfde09.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 129,
#    'id': 282299,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 56,
#      'name': "Shoot 'Em Up",
#      'slug': 'shoot-em-up',
#      'language': 'eng',
#      'games_count': 4261,
#      'image_background': 'https://media.rawg.io/media/screenshots/702/702133bcb0b3acc9b665372e32bee808.jpeg'},
#     {'id': 882,
#      'name': 'Game Boy',
#      'slug': 'game-boy',
#      'language': 'eng',
#      'games_count': 1218,
#      'image_background': 'https://media.rawg.io/media/screenshots/3c8/3c85d2dd26d4a420e469c80d35d42911.jpg'},
#     {'id': 2781,
#      'name': 'boss-rush',
#      'slug': 'boss-rush',
#      'language': 'eng',
#      'games_count': 13,
#      'image_background': 'https://media.rawg.io/media/screenshots/7bf/7bfe1d4955a58d0ac13eaaa555e77f15.jpg'},
#     {'id': 7055,
#      'name': 'anniversary',
#      'slug': 'anniversary',
#      'language': 'eng',
#      'games_count': 6,
#      'image_background': 'https://media.rawg.io/media/screenshots/632/63272d8f1fe378fa1d36412dcb9538df.jpg'},
#     {'id': 9493,
#      'name': '1989',
#      'slug': 'tag-37',
#      'language': 'eng',
#      'games_count': 5,
#      'image_background': 'https://media.rawg.io/media/screenshots/90e/90e056e8a408612ec2eec18933e6c118.jpg'},
#     {'id': 36325,
#      'name': '2019',
#      'slug': 'tag-145',
#      'language': 'eng',
#      'games_count': 81,
#      'image_background': 'https://media.rawg.io/media/screenshots/0dd/0dd05f83a5987dcc6f018bd7a99a6218.jpg'},
#     {'id': 37246,
#      'name': '30th',
#      'slug': '30th',
#      'language': 'eng',
#      'games_count': 1,
#      'image_background': 'https://media.rawg.io/media/screenshots/40c/40cb14d5186fb30fc1a1705c8dbfde09.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/40c/40cb14d5186fb30fc1a1705c8dbfde09.jpg'},
#     {'id': 1798706,
#      'image': 'https://media.rawg.io/media/screenshots/d4a/d4a4715bcb4d8eb562e9db4414aca4c9.jpg'},
#     {'id': 1798707,
#      'image': 'https://media.rawg.io/media/screenshots/b0e/b0e875d267816e5fe4f53108c2bd4378.jpg'},
#     {'id': 1798708,
#      'image': 'https://media.rawg.io/media/screenshots/838/83862104ad01fb98e834a1e7e679d1ae.jpg'},
#     {'id': 1798709,
#      'image': 'https://media.rawg.io/media/screenshots/029/0294588f3c72ee191233f50335a8a2aa.jpg'},
#     {'id': 1798710,
#      'image': 'https://media.rawg.io/media/screenshots/12e/12e26d4ad42641e8750536bee27bd5e2.jpg'},
#     {'id': 1798711,
#      'image': 'https://media.rawg.io/media/screenshots/40c/40cb14d5186fb30fc1a1705c8dbfde09.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 2, 'name': 'Shooter', 'slug': 'shooter'},
#     {'id': 4, 'name': 'Action', 'slug': 'action'}]},
#   {'slug': 'the-side-quest',
#    'name': 'The Side Quest',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/735/7354484b05bf92a63d92656886f1a8b9.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 81,
#    'id': 282300,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 45,
#      'name': '2D',
#      'slug': '2d',
#      'language': 'eng',
#      'games_count': 47748,
#      'image_background': 'https://media.rawg.io/media/games/91c/91c4f377c1e09755b60a0102c5252843.jpg'},
#     {'id': 64,
#      'name': 'Fantasy',
#      'slug': 'fantasy',
#      'language': 'eng',
#      'games_count': 7223,
#      'image_background': 'https://media.rawg.io/media/games/aa3/aa36ba4b486a03ddfaef274fb4f5afd4.jpg'},
#     {'id': 122,
#      'name': 'Pixel Graphics',
#      'slug': 'pixel-graphics',
#      'language': 'eng',
#      'games_count': 22577,
#      'image_background': 'https://media.rawg.io/media/screenshots/f3b/f3b3c2e6ea6aac2cfaf4ccfa4aaa08f4.jpg'},
#     {'id': 604,
#      'name': 'simple',
#      'slug': 'simple',
#      'language': 'eng',
#      'games_count': 4515,
#      'image_background': 'https://media.rawg.io/media/screenshots/436/4360c66c192ab35ec706b4e4d61d6f2c.jpg'},
#     {'id': 662,
#      'name': 'RPG Maker',
#      'slug': 'rpg-maker',
#      'language': 'eng',
#      'games_count': 3581,
#      'image_background': 'https://media.rawg.io/media/screenshots/07d/07db693969f2d918aaba6adfbb0a4819.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/735/7354484b05bf92a63d92656886f1a8b9.jpg'},
#     {'id': 1798712,
#      'image': 'https://media.rawg.io/media/screenshots/9f2/9f243010c7d3e8c10ba914c5c6512f0c.jpg'},
#     {'id': 1798713,
#      'image': 'https://media.rawg.io/media/screenshots/745/745c572c4287a2bbc8ccf43bb98e6770.jpg'},
#     {'id': 1798714,
#      'image': 'https://media.rawg.io/media/screenshots/735/7354484b05bf92a63d92656886f1a8b9.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}}],
#    'genres': [{'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#   {'slug': 'voices-near-the-stroke-of-midnight',
#    'name': 'Voices Near the Stroke of Midnight',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}},
#     {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/77a/77a15ef18a1d62f24ce3a595d21ba9e6.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 20,
#    'id': 282307,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 111,
#      'name': 'Short',
#      'slug': 'short',
#      'language': 'eng',
#      'games_count': 8318,
#      'image_background': 'https://media.rawg.io/media/games/0be/0bea0a08a4d954337305391b778a7f37.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/77a/77a15ef18a1d62f24ce3a595d21ba9e6.jpg'},
#     {'id': 1798727,
#      'image': 'https://media.rawg.io/media/screenshots/77a/77a15ef18a1d62f24ce3a595d21ba9e6.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}},
#     {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}}],
#    'genres': []},
#   {'slug': 'kungfucious',
#    'name': 'Kungfucious',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/c57/c5792edc276136f3f9b8f414c992d0de.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 245,
#    'id': 282322,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 37,
#      'name': 'Sandbox',
#      'slug': 'sandbox',
#      'language': 'eng',
#      'games_count': 2268,
#      'image_background': 'https://media.rawg.io/media/games/e3d/e3ddc524c6292a435d01d97cc5f42ea7.jpg'},
#     {'id': 34,
#      'name': 'Violent',
#      'slug': 'violent',
#      'language': 'eng',
#      'games_count': 3352,
#      'image_background': 'https://media.rawg.io/media/games/29c/29ccb3d344cf9d3f5b81b7a85361a178.jpg'},
#     {'id': 33,
#      'name': 'VR',
#      'slug': 'vr',
#      'language': 'eng',
#      'games_count': 6371,
#      'image_background': 'https://media.rawg.io/media/screenshots/f24/f24122a8e3d30ec3e99472e3e826d0cb.jpg'},
#     {'id': 885,
#      'name': 'vive',
#      'slug': 'vive',
#      'language': 'eng',
#      'games_count': 326,
#      'image_background': 'https://media.rawg.io/media/screenshots/381/381d0f0756540dcc124c93444ff56b10.jpg'},
#     {'id': 950,
#      'name': 'Oculus Rift',
#      'slug': 'oculus-rift',
#      'language': 'eng',
#      'games_count': 474,
#      'image_background': 'https://media.rawg.io/media/screenshots/b46/b46117b550883eefce476dcb8bed8c52.jpg'},
#     {'id': 4678,
#      'name': 'kung-fu',
#      'slug': 'kung-fu',
#      'language': 'eng',
#      'games_count': 15,
#      'image_background': 'https://media.rawg.io/media/screenshots/55b/55bf4561ae2ea45f9336690d84b0b962.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/c57/c5792edc276136f3f9b8f414c992d0de.jpg'},
#     {'id': 1798761,
#      'image': 'https://media.rawg.io/media/screenshots/90c/90c6050a87d48fa9694f6ba449b280cb.jpg'},
#     {'id': 1798762,
#      'image': 'https://media.rawg.io/media/screenshots/b65/b651a604960f61970b593a0e21644979.jpg'},
#     {'id': 1798763,
#      'image': 'https://media.rawg.io/media/screenshots/330/330010bf2d1fa4468da18434834f66db.jpg'},
#     {'id': 1798764,
#      'image': 'https://media.rawg.io/media/screenshots/cf4/cf4bfe970bc28e1aa9d152f070800b2c.jpg'},
#     {'id': 1798765,
#      'image': 'https://media.rawg.io/media/screenshots/c57/c5792edc276136f3f9b8f414c992d0de.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 4, 'name': 'Action', 'slug': 'action'},
#     {'id': 14, 'name': 'Simulation', 'slug': 'simulation'}]},
#   {'slug': 'dogfighter-3d',
#    'name': 'Dogfighter 3D',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/067/067af4978a1bc0093e9ffc2c8932f9be.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 36,
#    'id': 282332,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 460,
#      'name': 'Endless',
#      'slug': 'endless',
#      'language': 'eng',
#      'games_count': 7351,
#      'image_background': 'https://media.rawg.io/media/screenshots/b0b/b0b34a26c390dde54185488fdcea4248.jpeg'},
#     {'id': 571,
#      'name': '3D',
#      'slug': '3d',
#      'language': 'eng',
#      'games_count': 15274,
#      'image_background': 'https://media.rawg.io/media/games/3e3/3e355e1b8a5ee47f4c76e28e3055236d.jpg'},
#     {'id': 1896,
#      'name': 'plane',
#      'slug': 'plane',
#      'language': 'eng',
#      'games_count': 1097,
#      'image_background': 'https://media.rawg.io/media/screenshots/434/4346f9e6e201d4b11be19e52b9b19965_O0bXe7R.jpg'},
#     {'id': 26712,
#      'name': 'dogfighter',
#      'slug': 'dogfighter',
#      'language': 'eng',
#      'games_count': 2,
#      'image_background': 'https://media.rawg.io/media/screenshots/603/60360a2237b8e4aa8406df8f08449481.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/067/067af4978a1bc0093e9ffc2c8932f9be.jpg'},
#     {'id': 1798781,
#      'image': 'https://media.rawg.io/media/screenshots/808/808fa9aa30e296e33ea140f6dde0c3e3.jpg'},
#     {'id': 1798782,
#      'image': 'https://media.rawg.io/media/screenshots/d9d/d9d7b5a61d11293245234a3aa0195452.jpg'},
#     {'id': 1798783,
#      'image': 'https://media.rawg.io/media/screenshots/067/067af4978a1bc0093e9ffc2c8932f9be.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 2, 'name': 'Shooter', 'slug': 'shooter'}]},
#   {'slug': 'fairground-2-the-ride-simulation',
#    'name': 'Fairground 2 - The Ride Simulation',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/43e/43ea8b10feaab8029592719a9c30ad20.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 415,
#    'id': 268399,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 40847,
#      'name': 'Steam Achievements',
#      'slug': 'steam-achievements',
#      'language': 'eng',
#      'games_count': 17425,
#      'image_background': 'https://media.rawg.io/media/games/73e/73eecb8909e0c39fb246f457b5d6cbbe.jpg'},
#     {'id': 31,
#      'name': 'Singleplayer',
#      'slug': 'singleplayer',
#      'language': 'eng',
#      'games_count': 61255,
#      'image_background': 'https://media.rawg.io/media/games/88c/88c5b4d7c80276c03ff62aebb1a99ad4.jpg'},
#     {'id': 42398,
#      'name': 'Инди',
#      'slug': 'indi-2',
#      'language': 'rus',
#      'games_count': 27801,
#      'image_background': 'https://media.rawg.io/media/games/929/9295e55ce69cf5337c567983cf8b4137.jpeg'},
#     {'id': 42413,
#      'name': 'Симулятор',
#      'slug': 'simuliator',
#      'language': 'rus',
#      'games_count': 7748,
#      'image_background': 'https://media.rawg.io/media/screenshots/9b9/9b9d1fcf7b2a6cc7926328c83e13a66a.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/43e/43ea8b10feaab8029592719a9c30ad20.jpg'},
#     {'id': 1746097,
#      'image': 'https://media.rawg.io/media/screenshots/baf/baff33e27fa7c53538957932192d95fa.jpg'},
#     {'id': 1746098,
#      'image': 'https://media.rawg.io/media/screenshots/baf/baf7b818ba5b924c5ee9dcd1f3f7aee4.jpg'},
#     {'id': 1746099,
#      'image': 'https://media.rawg.io/media/screenshots/80a/80aea956d993ae614b4a3eabd9070917.jpg'},
#     {'id': 1746100,
#      'image': 'https://media.rawg.io/media/screenshots/fb1/fb129af30c31c4a85eb6bfaeeb1257f9.jpg'},
#     {'id': 1746101,
#      'image': 'https://media.rawg.io/media/screenshots/609/60959f2d12149fd18b3cf03a12e54951.jpg'},
#     {'id': 1746102,
#      'image': 'https://media.rawg.io/media/screenshots/c3b/c3b17ff29b6d7f4a4e5f8b60964c2a55.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 51, 'name': 'Indie', 'slug': 'indie'},
#     {'id': 14, 'name': 'Simulation', 'slug': 'simulation'}]},
#   {'slug': 'critters-for-sale',
#    'name': 'Critters for Sale',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}},
#     {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#     {'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/5c8/5c8f57ee483dfb0611edda97e029efb7.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [{'id': 4,
#      'title': 'recommended',
#      'count': 1,
#      'percent': 100.0}],
#    'ratings_count': 1,
#    'reviews_text_count': 0,
#    'added': 4,
#    'added_by_status': {'yet': 2, 'owned': 2},
#    'metacritic': None,
#    'suggestions_count': 513,
#    'id': 320408,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 40833,
#      'name': 'Captions available',
#      'slug': 'captions-available',
#      'language': 'eng',
#      'games_count': 967,
#      'image_background': 'https://media.rawg.io/media/screenshots/e26/e269338124c3c5a991e0f2570f960009.jpg'},
#     {'id': 45,
#      'name': '2D',
#      'slug': '2d',
#      'language': 'eng',
#      'games_count': 65480,
#      'image_background': 'https://media.rawg.io/media/games/5f4/5f4780690dbf04900cbac5f05b9305f3.jpg'},
#     {'id': 40847,
#      'name': 'Steam Achievements',
#      'slug': 'steam-achievements',
#      'language': 'eng',
#      'games_count': 18291,
#      'image_background': 'https://media.rawg.io/media/games/64b/64bb90ca6b1df8a36d710f6542111142.jpg'},
#     {'id': 8,
#      'name': 'First-Person',
#      'slug': 'first-person',
#      'language': 'eng',
#      'games_count': 7478,
#      'image_background': 'https://media.rawg.io/media/games/7fa/7fa0b586293c5861ee32490e953a4996.jpg'},
#     {'id': 26,
#      'name': 'Gore',
#      'slug': 'gore',
#      'language': 'eng',
#      'games_count': 3126,
#      'image_background': 'https://media.rawg.io/media/games/c6b/c6bfece1daf8d06bc0a60632ac78e5bf.jpg'},
#     {'id': 16,
#      'name': 'Horror',
#      'slug': 'horror',
#      'language': 'eng',
#      'games_count': 13568,
#      'image_background': 'https://media.rawg.io/media/games/aa3/aa36ba4b486a03ddfaef274fb4f5afd4.jpg'},
#     {'id': 122,
#      'name': 'Pixel Graphics',
#      'slug': 'pixel-graphics',
#      'language': 'eng',
#      'games_count': 30545,
#      'image_background': 'https://media.rawg.io/media/screenshots/4f4/4f4722571e32954af43a4508607c1748.jpg'},
#     {'id': 141,
#      'name': 'Point & Click',
#      'slug': 'point-click',
#      'language': 'eng',
#      'games_count': 4814,
#      'image_background': 'https://media.rawg.io/media/games/471/4712c9ac591f556f553556b864a7e92b.jpg'},
#     {'id': 285,
#      'name': 'Psychological',
#      'slug': 'psychological',
#      'language': 'eng',
#      'games_count': 282,
#      'image_background': 'https://media.rawg.io/media/games/66c/66cad7e826e08682192392e37cce3cd1.jpg'},
#     {'id': 31,
#      'name': 'Singleplayer',
#      'slug': 'singleplayer',
#      'language': 'eng',
#      'games_count': 75269,
#      'image_background': 'https://media.rawg.io/media/games/d1a/d1a2e99ade53494c6330a0ed945fe823.jpg'},
#     {'id': 46,
#      'name': 'Surreal',
#      'slug': 'surreal',
#      'language': 'eng',
#      'games_count': 1879,
#      'image_background': 'https://media.rawg.io/media/screenshots/0f5/0f5fafb33254682411856dd0f85cd3df.jpg'},
#     {'id': 34,
#      'name': 'Violent',
#      'slug': 'violent',
#      'language': 'eng',
#      'games_count': 3692,
#      'image_background': 'https://media.rawg.io/media/games/7f0/7f021d4a3577ac9d591a628a431fc2e5.jpg'},
#     {'id': 90,
#      'name': 'Visual Novel',
#      'slug': 'visual-novel',
#      'language': 'eng',
#      'games_count': 1304,
#      'image_background': 'https://media.rawg.io/media/screenshots/ba6/ba6b1e6e52e4cad6a59b6a9193853db7.jpg'},
#     {'id': 1030,
#      'name': 'Black and White',
#      'slug': 'black-and-white',
#      'language': 'eng',
#      'games_count': 1176,
#      'image_background': 'https://media.rawg.io/media/screenshots/615/6151f113de114019699e0c02e135942e.jpg'},
#     {'id': 2468,
#      'name': 'paranormal',
#      'slug': 'paranormal',
#      'language': 'eng',
#      'games_count': 18,
#      'image_background': 'https://media.rawg.io/media/screenshots/810/810d00bdd6d36274dce88542dffa4cfe.jpg'},
#     {'id': 42390,
#      'name': 'Решения с последствиями',
#      'slug': 'resheniia-s-posledstviiami',
#      'language': 'rus',
#      'games_count': 700,
#      'image_background': 'https://media.rawg.io/media/games/efd/efd6b2cb621c41a2b6580d8ac260b8ba.jpg'},
#     {'id': 42393,
#      'name': 'Визуальная новелла',
#      'slug': 'vizualnaia-novella',
#      'language': 'rus',
#      'games_count': 1672,
#      'image_background': 'https://media.rawg.io/media/screenshots/e25/e253cc4df0c2604ec2b12cab8b45d58a.jpg'},
#     {'id': 42394,
#      'name': 'Глубокий сюжет',
#      'slug': 'glubokii-siuzhet',
#      'language': 'rus',
#      'games_count': 3061,
#      'image_background': 'https://media.rawg.io/media/games/fc1/fc1307a2774506b5bd65d7e8424664a7.jpg'},
#     {'id': 42402,
#      'name': 'Насилие',
#      'slug': 'nasilie',
#      'language': 'rus',
#      'games_count': 3043,
#      'image_background': 'https://media.rawg.io/media/games/fba/fbae1bcfae1feffda6a11fbc1c939420.jpg'},
#     {'id': 42415,
#      'name': 'Пиксельная графика',
#      'slug': 'pikselnaia-grafika',
#      'language': 'rus',
#      'games_count': 2702,
#      'image_background': 'https://media.rawg.io/media/games/054/054ab7dd5e83f84f1ec8bedf849b627f.jpg'},
#     {'id': 42443,
#      'name': 'Криминал',
#      'slug': 'kriminal',
#      'language': 'rus',
#      'games_count': 177,
#      'image_background': 'https://media.rawg.io/media/games/233/233cdc08cce0228f6f35222eca3bff92.jpg'},
#     {'id': 42477,
#      'name': 'Мрачная',
#      'slug': 'mrachnaia',
#      'language': 'rus',
#      'games_count': 861,
#      'image_background': 'https://media.rawg.io/media/games/810/810470973732a8deec761637b36de567.jpg'},
#     {'id': 42478,
#      'name': 'Магия',
#      'slug': 'magiia',
#      'language': 'rus',
#      'games_count': 377,
#      'image_background': 'https://media.rawg.io/media/games/aa2/aa25254dbfa5b2073595bf69d8c8bac4.jpg'},
#     {'id': 42491,
#      'name': 'Мясо',
#      'slug': 'miaso',
#      'language': 'rus',
#      'games_count': 2555,
#      'image_background': 'https://media.rawg.io/media/games/806/8060a7663364ac23e15480728938d6f3.jpg'},
#     {'id': 42508,
#      'name': 'Нелинейность',
#      'slug': 'nelineinost',
#      'language': 'rus',
#      'games_count': 435,
#      'image_background': 'https://media.rawg.io/media/games/052/052f9afc7aaeea3e2c5d46eafa92c64e.jpg'},
#     {'id': 42513,
#      'name': 'Триллер',
#      'slug': 'triller',
#      'language': 'rus',
#      'games_count': 159,
#      'image_background': 'https://media.rawg.io/media/games/64a/64a7789943fe9f9d9c93f3a286ee7b20.jpg'},
#     {'id': 42556,
#      'name': 'Тайна',
#      'slug': 'taina',
#      'language': 'rus',
#      'games_count': 1011,
#      'image_background': 'https://media.rawg.io/media/games/b80/b80de593e66136f8a35c57960cc8fa3b.jpg'},
#     {'id': 42621,
#      'name': 'Путешествия во времени',
#      'slug': 'puteshestviia-vo-vremeni',
#      'language': 'rus',
#      'games_count': 92,
#      'image_background': 'https://media.rawg.io/media/games/9a1/9a18c226cf379272c698f26d2b79b3da.jpg'},
#     {'id': 42646,
#      'name': 'Беседы',
#      'slug': 'besedy',
#      'language': 'rus',
#      'games_count': 45,
#      'image_background': 'https://media.rawg.io/media/screenshots/2eb/2eb9c5713d8499b35355868be19e56b1.jpg'},
#     {'id': 42655,
#      'name': 'Психологическая',
#      'slug': 'psikhologicheskaia',
#      'language': 'rus',
#      'games_count': 235,
#      'image_background': 'https://media.rawg.io/media/games/598/598d272e2fc09f7f5362ddd37868a329.jpg'},
#     {'id': 42671,
#      'name': 'Динамические повествование',
#      'slug': 'dinamicheskie-povestvovanie',
#      'language': 'rus',
#      'games_count': 55,
#      'image_background': 'https://media.rawg.io/media/games/1c7/1c770e4c68021d1d78b704045e6182eb.jpg'},
#     {'id': 42672,
#      'name': 'Сюрреалистичная',
#      'slug': 'siurrealistichnaia',
#      'language': 'rus',
#      'games_count': 420,
#      'image_background': 'https://media.rawg.io/media/screenshots/65c/65c8b501f8c2a9c9386411d7b5210934.jpg'}],
#    'user_game': None,
#    'reviews_count': 1,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/5c8/5c8f57ee483dfb0611edda97e029efb7.jpg'},
#     {'id': 1798621,
#      'image': 'https://media.rawg.io/media/screenshots/260/260d5c05aa78e9bceee73b97d30485e1.jpg'},
#     {'id': 1798622,
#      'image': 'https://media.rawg.io/media/screenshots/add/adde4cc9a36ce83b225cc72a882a418f.jpg'},
#     {'id': 1798623,
#      'image': 'https://media.rawg.io/media/screenshots/0f3/0f37d720e7b80aa1da8b29675f60d27c.jpg'},
#     {'id': 1798624,
#      'image': 'https://media.rawg.io/media/screenshots/fca/fca4d43c0f3d4b1e762119b691e66390.jpg'},
#     {'id': 1798625,
#      'image': 'https://media.rawg.io/media/screenshots/a20/a20bcd76014b1235f7ce770809e9d5fd.jpg'},
#     {'id': 1798626,
#      'image': 'https://media.rawg.io/media/screenshots/72d/72d7e499c8755d1803d8e0f0444a1ccc.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}},
#     {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}}],
#    'genres': [{'id': 51, 'name': 'Indie', 'slug': 'indie'},
#     {'id': 3, 'name': 'Adventure', 'slug': 'adventure'},
#     {'id': 4, 'name': 'Action', 'slug': 'action'}]},
#   {'slug': 'cyberdrome',
#    'name': 'Cyberdrome',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}}],
#    'released': '2019-01-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/836/836b8f3fa2024699aa51cb66756cf8c6.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 2,
#    'added_by_status': {'owned': 2},
#    'metacritic': None,
#    'suggestions_count': 448,
#    'id': 275687,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 40836,
#      'name': 'Full controller support',
#      'slug': 'full-controller-support',
#      'language': 'eng',
#      'games_count': 8166,
#      'image_background': 'https://media.rawg.io/media/games/73e/73eecb8909e0c39fb246f457b5d6cbbe.jpg'},
#     {'id': 40847,
#      'name': 'Steam Achievements',
#      'slug': 'steam-achievements',
#      'language': 'eng',
#      'games_count': 17553,
#      'image_background': 'https://media.rawg.io/media/games/490/49016e06ae2103881ff6373248843069.jpg'},
#     {'id': 79,
#      'name': 'Free to Play',
#      'slug': 'free-to-play',
#      'language': 'eng',
#      'games_count': 2699,
#      'image_background': 'https://media.rawg.io/media/screenshots/848/848253347dc93c762bfd51c7e4989b8f.jpg'},
#     {'id': 31,
#      'name': 'Singleplayer',
#      'slug': 'singleplayer',
#      'language': 'eng',
#      'games_count': 63684,
#      'image_background': 'https://media.rawg.io/media/games/148/1485f72434101885b098d4290bf0ba67.jpg'},
#     {'id': 42392,
#      'name': 'Приключение',
#      'slug': 'prikliuchenie',
#      'language': 'rus',
#      'games_count': 15653,
#      'image_background': 'https://media.rawg.io/media/games/16b/16b1b7b36e2042d1128d5a3e852b3b2f.jpg'},
#     {'id': 42398,
#      'name': 'Инди',
#      'slug': 'indi-2',
#      'language': 'rus',
#      'games_count': 28033,
#      'image_background': 'https://media.rawg.io/media/games/d0f/d0f91fe1d92332147e5db74e207cfc7a.jpg'},
#     {'id': 42417,
#      'name': 'Экшен',
#      'slug': 'ekshen',
#      'language': 'rus',
#      'games_count': 17458,
#      'image_background': 'https://media.rawg.io/media/games/562/562553814dd54e001a541e4ee83a591c.jpg'},
#     {'id': 42470,
#      'name': 'Киберпанк',
#      'slug': 'kiberpank',
#      'language': 'rus',
#      'games_count': 370,
#      'image_background': 'https://media.rawg.io/media/screenshots/ef7/ef75a120ae2fc8ee7313664b01b4fad5.jpg'},
#     {'id': 42538,
#      'name': 'Бесплатная игра',
#      'slug': 'besplatnaia-igra',
#      'language': 'rus',
#      'games_count': 2692,
#      'image_background': 'https://media.rawg.io/media/games/d07/d0790809a13027251b6d0f4dc7538c58.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/836/836b8f3fa2024699aa51cb66756cf8c6.jpg'},
#     {'id': 1772186,
#      'image': 'https://media.rawg.io/media/screenshots/b3c/b3c832ed4f13ffec5486bc6b58d12a54.jpg'},
#     {'id': 1772187,
#      'image': 'https://media.rawg.io/media/screenshots/2c0/2c0cd5e453e238ac1fe7c3f709cdc96f.jpg'},
#     {'id': 1772188,
#      'image': 'https://media.rawg.io/media/screenshots/831/83109fef117d32819c8085a4a303253f.jpg'},
#     {'id': 1772189,
#      'image': 'https://media.rawg.io/media/screenshots/cc6/cc6a7bf6c9e43c0231c2cccc1e8a0e6e.jpg'},
#     {'id': 1772190,
#      'image': 'https://media.rawg.io/media/screenshots/5ea/5ead8fdc64abcdc75cbd1957673679af.jpg'},
#     {'id': 1772191,
#      'image': 'https://media.rawg.io/media/screenshots/2d3/2d36975074e9dc085de821910413f560.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 51, 'name': 'Indie', 'slug': 'indie'},
#     {'id': 3, 'name': 'Adventure', 'slug': 'adventure'},
#     {'id': 4, 'name': 'Action', 'slug': 'action'}]},
#   {'slug': 'strange-and-weird-museum',
#    'name': 'Strange and weird museum',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}}],
#    'released': '2019-01-02',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/b48/b48fd0793b0bdbaeca52ce1ba566c7c2.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 284,
#    'id': 277985,
#    'score': None,
#    'clip': None,
# ...
#     {'id': 31,
#      'name': 'Singleplayer',
#      'slug': 'singleplayer',
#      'language': 'eng',
#      'games_count': 61255,
#      'image_background': 'https://media.rawg.io/media/games/88c/88c5b4d7c80276c03ff62aebb1a99ad4.jpg'},
#     {'id': 65,
#      'name': 'Tower Defense',
#      'slug': 'tower-defense',
#      'language': 'eng',
#      'games_count': 2116,
#      'image_background': 'https://media.rawg.io/media/screenshots/333/333e7121b588929dcf08eb99aff39ce5.jpg'},
#     {'id': 2664,
#      'name': 'prototype',
#      'slug': 'prototype',
#      'language': 'eng',
#      'games_count': 1887,
#      'image_background': 'https://media.rawg.io/media/games/0fa/0fa2ea78b337afaa4b216bc368d9312c.jpg'},
#     {'id': 4706,
#      'name': 'knights',
#      'slug': 'knights',
#      'language': 'eng',
#      'games_count': 37,
#      'image_background': 'https://media.rawg.io/media/screenshots/d22/d22824c3803d8e9bbf8ec3e6a6d475cc.jpg'},
#     {'id': 5201,
#      'name': 'wip',
#      'slug': 'wip',
#      'language': 'eng',
#      'games_count': 139,
#      'image_background': 'https://media.rawg.io/media/screenshots/663/66303f947a553e3e3a34fb580e4fb961.jpg'},
#     {'id': 10055,
#      'name': 'testing',
#      'slug': 'testing',
#      'language': 'eng',
#      'games_count': 14,
#      'image_background': 'https://media.rawg.io/media/screenshots/8ff/8ffe308d0cbdd111fac026b6dfb62aa6.jpg'},
#     {'id': 37213,
#      'name': 'artist-needed',
#      'slug': 'artist-needed',
#      'language': 'eng',
#      'games_count': 1,
#      'image_background': 'https://media.rawg.io/media/screenshots/eb3/eb38ca3766b3144a3f5b9a145723d915.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/eb3/eb38ca3766b3144a3f5b9a145723d915.jpg'},
#     {'id': 1798118,
#      'image': 'https://media.rawg.io/media/screenshots/158/158bb4cc74422fa7dbfdb3227f6964f5.jpg'},
#     {'id': 1798119,
#      'image': 'https://media.rawg.io/media/screenshots/eb3/eb38ca3766b3144a3f5b9a145723d915.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 10, 'name': 'Strategy', 'slug': 'strategy'}]},
#   {'slug': 'phobia-detournement-damnesia',
#    'name': "Phobia - Détournement d'amnesia",
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-02',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/d6a/d6a4f516d0688ed855a92f10a024d80c.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 73,
#    'id': 282104,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 16,
#      'name': 'Horror',
#      'slug': 'horror',
#      'language': 'eng',
#      'games_count': 10573,
#      'image_background': 'https://media.rawg.io/media/screenshots/d76/d76ec02d681a20848ae78adce6324701.jpg'},
#     {'id': 3774,
#      'name': 'amnesia',
#      'slug': 'amnesia',
#      'language': 'eng',
#      'games_count': 13,
#      'image_background': 'https://media.rawg.io/media/screenshots/12a/12aae38ec749fe7b21cf9fa93ca99e17.jpg'},
#     {'id': 37219,
#      'name': 'detournement',
#      'slug': 'detournement',
#      'language': 'eng',
#      'games_count': 1,
#      'image_background': 'https://media.rawg.io/media/screenshots/d6a/d6a4f516d0688ed855a92f10a024d80c.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/d6a/d6a4f516d0688ed855a92f10a024d80c.jpg'},
#     {'id': 1798172,
#      'image': 'https://media.rawg.io/media/screenshots/e4e/e4ed00ec16750fae132cd403101d6b7c.jpg'},
#     {'id': 1798173,
#      'image': 'https://media.rawg.io/media/screenshots/d6a/d6a4f516d0688ed855a92f10a024d80c.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': []},
#   {'slug': 'battle-factory',
#    'name': 'Battle-Factory',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 21, 'name': 'Android', 'slug': 'android'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-02',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/642/6428561234b17d144f054ecf0e34166a.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 18,
#    'id': 282105,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 72,
#      'name': 'Local Multiplayer',
#      'slug': 'local-multiplayer',
#      'language': 'eng',
#      'games_count': 6989,
#      'image_background': 'https://media.rawg.io/media/games/1e5/1e5e33b88be978f451196a751424a72e.jpg'},
#     {'id': 7,
#      'name': 'Multiplayer',
#      'slug': 'multiplayer',
#      'language': 'eng',
#      'games_count': 18474,
#      'image_background': 'https://media.rawg.io/media/games/490/49016e06ae2103881ff6373248843069.jpg'},
#     {'id': 101,
#      'name': 'Turn-Based Strategy',
#      'slug': 'turn-based-strategy',
#      'language': 'eng',
#      'games_count': 1409,
#      'image_background': 'https://media.rawg.io/media/games/8ca/8ca40b562a755d6a0e30d48e6c74b178.jpg'},
#     {'id': 607,
#      'name': 'Unity',
#      'slug': 'unity',
#      'language': 'eng',
#      'games_count': 14167,
#      'image_background': 'https://media.rawg.io/media/screenshots/918/9182b7f42353ba323624de7dcc63bdfd.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/642/6428561234b17d144f054ecf0e34166a.jpg'},
#     {'id': 1798174,
#      'image': 'https://media.rawg.io/media/screenshots/642/6428561234b17d144f054ecf0e34166a.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 8, 'name': 'Android', 'slug': 'android'}}],
#    'genres': [{'id': 10, 'name': 'Strategy', 'slug': 'strategy'}]},
#   {'slug': 'collector-jinvira',
#    'name': 'Collector (Jinvira)',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-02',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/168/1680d798f1a5007994ae3635c6f0e14d.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 7,
#    'id': 282109,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 2799,
#      'name': 'blue',
#      'slug': 'blue',
#      'language': 'eng',
#      'games_count': 742,
#      'image_background': 'https://media.rawg.io/media/screenshots/4ad/4ad4c327776d2b573d21f11020016786.jpg'},
#     {'id': 4424,
#      'name': 'cubes',
#      'slug': 'cubes',
#      'language': 'eng',
#      'games_count': 581,
#      'image_background': 'https://media.rawg.io/media/screenshots/5bb/5bbd71548240703f3bc42cee7c87972d.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/168/1680d798f1a5007994ae3635c6f0e14d.jpg'},
#     {'id': 1798188,
#      'image': 'https://media.rawg.io/media/screenshots/168/1680d798f1a5007994ae3635c6f0e14d.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': []},
#   {'slug': 'danger-dudes',
#    'name': 'Danger Dudes',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-02',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/f5d/f5db15c01a37e676a03fb68a9c194471.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 26,
#    'id': 282118,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 123,
#      'name': 'Comedy',
#      'slug': 'comedy',
#      'language': 'eng',
#      'games_count': 3664,
#      'image_background': 'https://media.rawg.io/media/games/a3c/a3c529a12c896c0ef02db5b4741de2ba.jpg'},
#     {'id': 72,
#      'name': 'Local Multiplayer',
#      'slug': 'local-multiplayer',
#      'language': 'eng',
#      'games_count': 6989,
#      'image_background': 'https://media.rawg.io/media/games/1e5/1e5e33b88be978f451196a751424a72e.jpg'},
#     {'id': 571,
#      'name': '3D',
#      'slug': '3d',
#      'language': 'eng',
#      'games_count': 15274,
#      'image_background': 'https://media.rawg.io/media/games/3e3/3e355e1b8a5ee47f4c76e28e3055236d.jpg'},
#     {'id': 631,
#      'name': 'Low-poly',
#      'slug': 'low-poly',
#      'language': 'eng',
#      'games_count': 2930,
#      'image_background': 'https://media.rawg.io/media/screenshots/bc3/bc3092dfc95ca8313eea2998eb52787e.jpg'},
#     {'id': 833,
#      'name': 'brawler',
#      'slug': 'brawler',
#      'language': 'eng',
#      'games_count': 257,
#      'image_background': 'https://media.rawg.io/media/screenshots/d8b/d8ba1d74c14179c0b7ee027c97695f28.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/f5d/f5db15c01a37e676a03fb68a9c194471.jpg'},
#     {'id': 1798235,
#      'image': 'https://media.rawg.io/media/screenshots/f5d/f5db15c01a37e676a03fb68a9c194471.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 6, 'name': 'Fighting', 'slug': 'fighting'}]},
#   {'slug': 'abooof-driving-simulator',
#    'name': 'ABoOoF Driving simulator',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 171, 'name': 'Web', 'slug': 'web'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-02',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/74c/74c817f958cc9bb81b63edd1f4f0c4ad.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 86,
#    'id': 282126,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 45,
#      'name': '2D',
#      'slug': '2d',
#      'language': 'eng',
#      'games_count': 47748,
#      'image_background': 'https://media.rawg.io/media/games/91c/91c4f377c1e09755b60a0102c5252843.jpg'},
#     {'id': 130,
#      'name': 'Driving',
#      'slug': 'driving',
#      'language': 'eng',
#      'games_count': 2532,
#      'image_background': 'https://media.rawg.io/media/screenshots/35c/35ca6e9bc8041e77c16ee157ee428745.jpg'},
#     {'id': 122,
#      'name': 'Pixel Graphics',
#      'slug': 'pixel-graphics',
#      'language': 'eng',
#      'games_count': 22577,
#      'image_background': 'https://media.rawg.io/media/screenshots/f3b/f3b3c2e6ea6aac2cfaf4ccfa4aaa08f4.jpg'},
#     {'id': 571,
#      'name': '3D',
#      'slug': '3d',
#      'language': 'eng',
#      'games_count': 15274,
#      'image_background': 'https://media.rawg.io/media/games/3e3/3e355e1b8a5ee47f4c76e28e3055236d.jpg'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/74c/74c817f958cc9bb81b63edd1f4f0c4ad.jpg'},
#     {'id': 1798269,
#      'image': 'https://media.rawg.io/media/screenshots/76d/76d5413165d1432cd92f9b07e8e37acc.jpg'},
#     {'id': 1798270,
#      'image': 'https://media.rawg.io/media/screenshots/eea/eea9c92b16679c317a596ed22263d830.jpg'},
#     {'id': 1798271,
#      'image': 'https://media.rawg.io/media/screenshots/0de/0deeda126a2edfe9c95a3fa46043b490.jpg'},
#     {'id': 1798272,
#      'image': 'https://media.rawg.io/media/screenshots/74c/74c817f958cc9bb81b63edd1f4f0c4ad.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 14, 'name': 'Web', 'slug': 'web'}}],
#    'genres': [{'id': 1, 'name': 'Racing', 'slug': 'racing'},
#     {'id': 14, 'name': 'Simulation', 'slug': 'simulation'}]},
#   {'slug': 'everyone_suffering',
#    'name': 'Everyone_suffering',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}},
#     {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}}],
#    'stores': [{'store': {'id': 9, 'name': 'itch.io', 'slug': 'itch'}}],
#    'released': '2019-01-02',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/486/4862c78c7f00c024f6a78b3a7da20f64.jpg',
#    'rating': 0.0,
#    'rating_top': 0,
#    'ratings': [],
#    'ratings_count': 0,
#    'reviews_text_count': 0,
#    'added': 0,
#    'added_by_status': None,
#    'metacritic': None,
#    'suggestions_count': 134,
#    'id': 282145,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 30,
#      'name': 'FPS',
#      'slug': 'fps',
#      'language': 'eng',
#      'games_count': 4182,
#      'image_background': 'https://media.rawg.io/media/games/157/15742f2f67eacff546738e1ab5c19d20.jpg'},
#     {'id': 111,
#      'name': 'Short',
#      'slug': 'short',
#      'language': 'eng',
#      'games_count': 8318,
#      'image_background': 'https://media.rawg.io/media/games/0be/0bea0a08a4d954337305391b778a7f37.jpg'},
#     {'id': 118,
#      'name': 'Story Rich',
#      'slug': 'story-rich',
#      'language': 'eng',
#      'games_count': 5331,
#      'image_background': 'https://media.rawg.io/media/games/bc0/bc06a29ceac58652b684deefe7d56099.jpg'},
#     {'id': 571,
#      'name': '3D',
#      'slug': '3d',
#      'language': 'eng',
#      'games_count': 15274,
#      'image_background': 'https://media.rawg.io/media/games/3e3/3e355e1b8a5ee47f4c76e28e3055236d.jpg'},
#     {'id': 1346,
#      'name': 'sad',
#      'slug': 'sad',
#      'language': 'eng',
#      'games_count': 183,
#      'image_background': 'https://img.itch.zone/aW1nLzIzOTg1NDgucG5n/original/rhudYy.png'}],
#    'user_game': None,
#    'reviews_count': 0,
#    'community_rating': 0,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/486/4862c78c7f00c024f6a78b3a7da20f64.jpg'},
#     {'id': 1798323,
#      'image': 'https://media.rawg.io/media/screenshots/e7d/e7d1e5f0aaebd2606ce7c864feba2b2c.jpg'},
#     {'id': 1798324,
#      'image': 'https://media.rawg.io/media/screenshots/df3/df36c654856100701bf0152369f01025.jpg'},
#     {'id': 1798325,
#      'image': 'https://media.rawg.io/media/screenshots/61c/61ce49895e6cd12f9f8588af334f3ceb.jpg'},
#     {'id': 1798326,
#      'image': 'https://media.rawg.io/media/screenshots/472/472d8b013e4a7994548e0696c2280166.jpg'},
#     {'id': 1798327,
#      'image': 'https://media.rawg.io/media/screenshots/486/4862c78c7f00c024f6a78b3a7da20f64.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}},
#     {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}}],
#    'genres': [{'id': 3, 'name': 'Adventure', 'slug': 'adventure'},
#     {'id': 4, 'name': 'Action', 'slug': 'action'}]}],
#  'user_platforms': False}

# %%
num = len(data['results'])
num
# Out:
# 40

# %% [markdown]
# ##### ID,Slug,name,game_pk required to identify the game
#
# 1) https://api.rawg.io/api/games/{id}/achievements get games achievemnts
# 2) https://api.rawg.io/api/games/{id}/movies - getting games trailers
# 3) https://api.rawg.io/api/genres - game genres
# 4) https://api.rawg.io/api/platforms - Video Game Platforms
# 5) https://api.rawg.io/api/platforms/lists/parents - PArent Platforms
# 6) https://api.rawg.io/api/stores - Video Game Storefronts

# %%
for i in range(0,num):
    print(data['results'][i]['name'])
    print(data['results'][i]['released'])
    print(data['results'][i]['platforms'][0]['platform']['id'])
    print(data['results'][i]['platforms'][0]['platform']['name'])
    print("-"*30)
# Out:
# EAT or FIGHT
# 2019-04-12
# 4
# PC
# ------------------------------
# Perses - Destructible Stealth Action Game
# 2019-04-12
# 4
# PC
# ------------------------------
# My Pet Rock (GF Build)
# 2019-04-12
# 4
# PC
# ------------------------------
# Mr. Sausage vs The Zomcats
# 2019-04-12
# 4
# PC
# ------------------------------
# 5secs
# 2019-04-12
# 4
# PC
# ------------------------------
# Life Of Ball
# 2019-04-12
# 4
# PC
# ------------------------------
# Deadly Zone
# 2019-04-12
# 4
# PC
# ------------------------------
# Tale Of Tom
# 2019-04-12
# 4
# PC
# ------------------------------
# Simple TownGen
# 2019-04-12
# 4
# PC
# ------------------------------
# Following
# 2019-04-12
# 4
# PC
# ------------------------------
# WEIRD BOXING (Game a Week)
# 2019-04-13
# 4
# PC
# ------------------------------
# Big Chungus 4 Operation Diamond
# 2019-04-12
# 4
# PC
# ------------------------------
# 22 Nights
# 2019-04-12
# 4
# PC
# ------------------------------
# C-Lone
# 2019-04-12
# 4
# PC
# ------------------------------
# Bezos Shopping Spree
# 2019-04-12
# 4
# PC
# ------------------------------
# Cat Jump (Hidden783)
# 2019-04-11
# 4
# PC
# ------------------------------
# Project Katharsis
# 2019-05-20
# 4
# PC
# ------------------------------
# To the Stars and Beyond!
# 2019-04-30
# 4
# PC
# ------------------------------
# Butterfly 2
# 2019-05-07
# 4
# PC
# ------------------------------
# Eilf
# 2019-04-30
# 4
# PC
# ------------------------------
# A five-day tour in the morgue
# 2019-04-22
# 4
# PC
# ------------------------------
# Trainspotting Simulator
# 2019-04-30
# 4
# PC
# ------------------------------
# Dungeon Pain Maniac
# 2019-05-06
# 4
# PC
# ------------------------------
# Late City Riders
# 2019-04-30
# 4
# PC
# ------------------------------
# THE RITUAL (Indie Horror Game)
# 2019-05-07
# 4
# PC
# ------------------------------
# Body Discovery
# 2019-04-29
# 4
# PC
# ------------------------------
# VR Party Pack
# 2019-05-03
# 4
# PC
# ------------------------------
# Nameless Worlds
# 2019-04-30
# 4
# PC
# ------------------------------
# Samael
# 2019-10-31
# 4
# PC
# ------------------------------
# Ulme Project
# 2019-01-06
# 4
# PC
# ------------------------------
# The Monster in the Woods
# 2019-04-19
# 4
# PC
# ------------------------------
# Basic UDP Client and NodeJS UDP Server
# 2019-04-19
# 4
# PC
# ------------------------------
# CoRBY
# 2019-04-18
# 4
# PC
# ------------------------------
# The Wheel (Warm Hands)
# 2019-04-18
# 4
# PC
# ------------------------------
# MEGA_SREKS_BY_715
# 2019-04-18
# 4
# PC
# ------------------------------
# The Red Witch
# 2019-04-18
# 4
# PC
# ------------------------------
# Greed Goblin
# 2019-04-18
# 4
# PC
# ------------------------------
# Dimensional Tunnel Pilot
# 2019-04-18
# 4
# PC
# ------------------------------
# Yummy!
# 2019-04-18
# 4
# PC
# ------------------------------
# Lexie The Takeover Demo
# 2019-04-18
# 4
# PC
# ------------------------------

# %%
#Platform Data frame
platform_id=[]
platform=[]
games_count = []
platforms = requests.get(f"https://api.rawg.io/api/platforms").json()
total_platforms = len(platforms['results'])
for n in range(0,total_platforms):
        platform_id.append(platforms['results'][n]['id'])
        platform.append(platforms['results'][n]['name'])
        games_count.append(platforms['results'][n]['games_count'])
df_platforms = pd.DataFrame({
            "platform_id":platform_id,
            "platform":platform,
            "games_count":games_count
        })
df_platforms
# Out:
#     platform_id            platform  games_count
# 0             4                  PC       274903
# 1           187       PlayStation 5          103
# 2             1            Xbox One         4021
# 3            18       PlayStation 4         5348
# 4           186     Xbox Series S/X           98
# 5             7     Nintendo Switch         3495
# 6             3                 iOS        67518
# 7            21             Android        33084
# 8             8        Nintendo 3DS         1717
# 9             9         Nintendo DS         2288
# 10           13        Nintendo DSi           28
# 11            5               macOS        61371
# 12            6               Linux        42614
# 13           14            Xbox 360         2690
# 14           80                Xbox          673
# 15           16       PlayStation 3         3608
# 16           15       PlayStation 2         1835
# 17           27         PlayStation         1524
# 18           19             PS Vita         1926
# 19           17                 PSP         1562
# 20           10               Wii U         1268
# 21           11                 Wii         2332
# 22          105            GameCube          635
# 23           83         Nintendo 64          354
# 24           24    Game Boy Advance          914
# 25           43      Game Boy Color          379
# 26           26            Game Boy          578
# 27           79                SNES          834
# 28           49                 NES          900
# 29           55   Classic Macintosh          629
# 30           41            Apple II          401
# 31          166   Commodore / Amiga         2026
# 32           28          Atari 7800           53
# 33           31          Atari 5200           61
# 34           23          Atari 2600          279
# 35           22     Atari Flashback           29
# 36           25         Atari 8-bit          298
# 37           34            Atari ST          812
# 38           46          Atari Lynx           55
# 39           50          Atari XEGS           22
# 40          167             Genesis          806
# 41          107         SEGA Saturn          297
# 42          119             SEGA CD          153
# 43          117            SEGA 32X           46
# 44           74  SEGA Master System          200
# 45          106           Dreamcast          342
# 46          111                 3DO           89
# 47          112              Jaguar           27
# 48           77           Game Gear          157
# 49           12             Neo Geo           96

# %%
#Stores Data Frames
store_id=[]
slug_name=[]
store_name=[]
total_games = []
domain = []
game_stores = requests.get(f"https://api.rawg.io/api/stores").json()
total_stores = len(game_stores['results'])
game_stores
for n in range(0,total_stores):
        store_id.append(game_stores['results'][n]['id'])
        slug_name.append(game_stores['results'][n]['slug'])
        store_name.append(game_stores['results'][n]['name'])
        total_games.append(game_stores['results'][n]['games_count'])
        domain.append(game_stores['results'][n]['domain'])

df_stores = pd.DataFrame({
           " store_id":store_id,
            "slug_name":slug_name,
            "store_name":store_name,
             "total_games":total_games,
            "domain":domain
        })
df_stores
# Out:
#     store_id          slug_name         store_name  total_games  \
# 0          1              steam              Steam        46181
# 1          3  playstation-store  PlayStation Store         7019
# 2          2         xbox-store         Xbox Store         3642
# 3          4     apple-appstore          App Store        65963
# 4          5                gog                GOG         2938
# 5          6           nintendo     Nintendo Store         7825
# 6          7            xbox360     Xbox 360 Store         1906
# 7          8        google-play        Google Play        16196
# 8          9               itch            itch.io       315227
# 9         11         epic-games         Epic Games          299
#
#                    domain
# 0  store.steampowered.com
# 1   store.playstation.com
# 2           microsoft.com
# 3          apps.apple.com
# 4                 gog.com
# 5            nintendo.com
# 6    marketplace.xbox.com
# 7         play.google.com
# 8                 itch.io
# 9           epicgames.com

# %%
#Genre Data frame
genre_id=[]
genre_name=[]
slug_name = []
games_count = []
genre_details = requests.get(f"https://api.rawg.io/api/https://api.rawg.io/api/genres").json()
total_genre = len(genre_details['results'])
for n in range(0,total_genre):
        genre_id.append(platforms['results'][n]['id'])
        genre_name.append(platforms['results'][n]['name'])
        slug_name.append(platforms['results'][n]['slug'])
        games_count.append(platforms['results'][n]['games_count'])
df_platforms = pd.DataFrame({
            "genre_id":genre_id,
            "genre_name":genre_id,
            "games_count":games_count
